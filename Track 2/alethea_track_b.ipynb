# %% [markdown]
# # Alethea AI — Track B Pipeline (Colab Notebook)
#
# This notebook implements the **Track B** requirements:
# 1) Prompt an LLM for continuous text
# 2) Call TTS per chunk
# 3) Run **Wav2Lip** per chunk
# 4) Stitch segments with **clean cross-fades** (FFmpeg/moviepy)
# 5) **Normalise audio** levels (EBU R128 via FFmpeg `loudnorm`)
#
# **Bonus**: CLI-like args section for segment length, simple retry logic for network calls, and a test that verifies identical FPS via `ffprobe`.

# %%
#@title Install dependencies & set up Wav2Lip
# If running in Colab, you can uncomment the next line
# !apt -y install ffmpeg

# Core Python libs
# !pip -q install transformers==4.42.4 torch torchaudio --extra-index-url https://download.pytorch.org/whl/cpu
# !pip -q install gTTS==2.5.3 moviepy==1.0.3 numpy==1.26.4 librosa==0.10.2.post1 soundfile==0.12.1 tqdm==4.66.4 pydub==0.25.1

# Wav2Lip setup
import os, sys, shutil, subprocess, json, math, random, time, textwrap, glob, shlex, tempfile, re, pathlib
from pathlib import Path

ROOT = Path.cwd()
W2L_DIR = ROOT / "Wav2Lip"
if not W2L_DIR.exists():
    # !git clone -q https://github.com/Rudrabha/Wav2Lip.git
    # %cd Wav2Lip
    # !pip -q install -r requirements.txt
    # %cd ..

# Download pretrained model weights
W2L_CKPT = W2L_DIR / "checkpoints/wav2lip_gan.pth"
W2L_DIR.joinpath("checkpoints").mkdir(exist_ok=True)
if not W2L_CKPT.exists():
    # !gdown -q --id 1l5l5qG8G4VqkI3QOcgpFv3G1qX3i6l2b -O Wav2Lip/checkpoints/wav2lip_gan.pth || echo "If gdown fails, please manually place the checkpoint."

print("Setup complete. Wav2Lip dir:", W2L_DIR)
# Out:
# Setup complete. Wav2Lip dir: /content/Wav2Lip

# %%
# Clean reinstall NumPy to a known-good build
# %pip uninstall -y numpy
# %pip install --no-cache-dir "numpy==1.26.4"

# Optional: pin a compatible stack (do AFTER the restart)
# %pip install --no-cache-dir "transformers==4.42.4" "tokenizers<0.20" "torch==2.3.1" "torchaudio==2.3.1" -U
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 8.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 157.7 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
# %pip install --no-cache-dir "librosa==0.10.2.post1" "numba>=0.58" "llvmlite>=0.41" "soundfile" "audioread" "pooch"
# Out:
# Collecting librosa==0.10.2.post1
#   Downloading librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Collecting numba>=0.58
#   Downloading numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting llvmlite>=0.41
#   Downloading llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.12.1)
# Requirement already satisfied: audioread in /usr/local/lib/python3.11/dist-packages (3.0.1)
# Requirement already satisfied: pooch in /usr/local/lib/python3.11/dist-packages (1.8.2)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.2.post1) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.2.post1) (1.16.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.2.post1) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.2.post1) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.2.post1) (4.4.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.2.post1) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.2.post1) (4.14.1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.2.post1) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.10.2.post1) (1.1.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch) (4.3.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from pooch) (25.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch) (2.32.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch) (2025.8.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa==0.10.2.post1) (3.6.0)
# Downloading librosa-0.10.2.post1-py3-none-any.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.1/260.1 kB 1.3 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 3.5 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 36.2 MB/s eta 0:00:00
# Installing collected packages: llvmlite, numba, librosa
# Successfully installed librosa-0.10.2.post1 llvmlite-0.44.0 numba-0.61.2

# %%
#@title Helper utilities (run shell, retry, ffprobe)
import subprocess, shlex, json, os, sys, time
from functools import wraps
from typing import List

def run_cmd(cmd: str, check=True):
    print(">>", cmd)
    proc = subprocess.run(shlex.split(cmd), stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
    print(proc.stdout)
    if check and proc.returncode != 0:
        raise RuntimeError(f"Command failed: {cmd}")
    return proc.stdout

def retry(max_attempts=3, delay=2.0):
    def deco(fn):
        @wraps(fn)
        def wrapper(*args, **kwargs):
            last = None
            for i in range(max_attempts):
                try:
                    return fn(*args, **kwargs)
                except Exception as e:
                    last = e
                    print(f"[retry] Attempt {i+1}/{max_attempts} failed: {e}")
                    time.sleep(delay)
            raise last
        return wrapper
    return deco

def ffprobe_fps(video_path: str) -> float:
    cmd = f'ffprobe -v error -select_streams v:0 -show_entries stream=r_frame_rate -of json "{video_path}"'
    out = run_cmd(cmd, check=False)
    try:
        info = json.loads(out)
        rate = info["streams"][0]["r_frame_rate"]
        num, den = rate.split("/")
        num, den = int(num), int(den)
        return num / den if den else float(num)
    except Exception:
        return -1.0

# %%
#@title Configuration (acts like CLI flags)
from dataclasses import dataclass
import os

@dataclass
class Config:
    prompt: str = "Tell me a short, uplifting story about perseverance and learning."  #@param {type:"string"}
    segments: int = 4 #@param {type:"integer"}
    segment_chars: int = 200 #@param {type:"integer"}
    voice_lang: str = "en" #@param ["en"]
    face_image_path: str = "/content/face.jpg" #@param {type:"string"}
    output_dir: str = "outputs" #@param {type:"string"}
    crossfade_s: float = 0.75 #@param {type:"number"}
    target_fps: int = 25 #@param {type:"integer"}
    audio_lufs: float = -16.0 #@param {type:"number"}

CFG = Config()
os.makedirs(CFG.output_dir, exist_ok=True)
print(CFG)
# Out:
# Config(prompt='Tell me a short, uplifting story about perseverance and learning.', segments=4, segment_chars=200, voice_lang='en', face_image_path='/content/face.jpg', output_dir='outputs', crossfade_s=0.75, target_fps=25, audio_lufs=-16.0)

# %% [markdown]
# ## 1) Generate continuous text with an LLM
#
# We use a small, local-friendly model (`distilgpt2`) via `transformers` to avoid paid APIs in Colab.

# %%
#@title LLM generation (local, offline)
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

tokenizer = AutoTokenizer.from_pretrained("distilgpt2")
model = AutoModelForCausalLM.from_pretrained("distilgpt2")
gen = pipeline("text-generation", model=model, tokenizer=tokenizer, device=-1)

@retry(max_attempts=2, delay=1.5)
def generate_continuous_text(prompt: str, approx_chars: int) -> str:
    out = gen(prompt, max_new_tokens=max(64, approx_chars//2), do_sample=True, top_p=0.95, temperature=0.9)[0]["generated_text"]
    # Basic clean-up
    return out.strip()

total_chars = CFG.segment_chars * CFG.segments + 80
full_text = generate_continuous_text(CFG.prompt, total_chars)
print("Generated length:", len(full_text))
print(full_text[:600], "...")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated length: 1999
# Tell me a short, uplifting story about perseverance and learning. I hope you would like to share it with your friends and family!
#
# So many stories have been submitted on social media, and are very interesting to follow. Some are more about the past and present, and others are more about the future. But these stories do not begin with a real story about a kid. It is about learning to be a part of what makes a great family, and of building relationships with loved ones and friends.
# As this story continues, we all will have the same questions as we do now. It will be fun to see what has happened  ...

# %%
#@title Split into segments
def split_text(text: str, n_segments: int, segment_chars: int) -> list:
    chunks = []
    buf = text.strip()
    while buf and len(chunks) < n_segments:
        chunk = buf[:segment_chars]
        # try not to cut in middle of sentence
        last = max(chunk.rfind("."), chunk.rfind("!"), chunk.rfind("?"))
        if last > int(segment_chars * 0.5):
            chunk = chunk[:last+1]
        chunks.append(chunk.strip())
        buf = buf[len(chunk):].lstrip()
    if len(chunks) < n_segments and buf:
        chunks.append(buf[:segment_chars].strip())
    return chunks

segments = split_text(full_text, CFG.segments, CFG.segment_chars)
for i, s in enumerate(segments):
    print(f"[Seg {i}] {len(s)} chars: {s[:120]}{'...' if len(s)>120 else ''}")
# Out:
# [Seg 0] 129 chars: Tell me a short, uplifting story about perseverance and learning. I hope you would like to share it with your friends an...
# [Seg 1] 168 chars: So many stories have been submitted on social media, and are very interesting to follow. Some are more about the past an...
# [Seg 2] 184 chars: But these stories do not begin with a real story about a kid. It is about learning to be a part of what makes a great fa...
# [Seg 3] 160 chars: As this story continues, we all will have the same questions as we do now. It will be fun to see what has happened and l...

# %% [markdown]
# ## 2) TTS per chunk (gTTS)
#
# Uses Google's free TTS (no key). If your environment blocks it, replace with Coqui TTS or any other engine.

# %%
#@title Synthesize TTS with gTTS
from pathlib import Path
import os, time
from gtts import gTTS

# ensure output dir exists
outdir = Path(CFG.output_dir)
outdir.mkdir(parents=True, exist_ok=True)

def tts_with_retry(text, lang, mp3_path, attempts=3, delay=1.5):
    for i in range(attempts):
        try:
            gTTS(text=text, lang=lang).save(str(mp3_path))
            return
        except Exception as e:
            print(f"[gTTS] attempt {i+1}/{attempts} failed: {e}")
            time.sleep(delay)
    raise RuntimeError("gTTS failed after retries")

audio_paths = []
for i, text in enumerate(segments):
    tmp_mp3 = outdir / f"seg_{i:03d}.mp3"
    out_wav = outdir / f"seg_{i:03d}.wav"
    tts_with_retry(text, CFG.voice_lang, tmp_mp3)
    run_cmd(f'ffmpeg -y -i "{tmp_mp3}" -ar 16000 -ac 1 "{out_wav}"')
    audio_paths.append(str(out_wav))

print("Audio files:", audio_paths)
# Out:
# >> ffmpeg -y -i "outputs/seg_000.mp3" -ar 16000 -ac 1 "outputs/seg_000.wav"
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x5b265cfe7040] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'outputs/seg_000.mp3':
#   Duration: 00:00:08.76, start: 0.000000, bitrate: 64 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'outputs/seg_000.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=       1kB time=00:00:00.00 bitrate=N/A speed=N/A
# size=     274kB time=00:00:08.75 bitrate= 256.1kbits/s speed= 468x
# video:0kB audio:274kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.027825%
#
# >> ffmpeg -y -i "outputs/seg_001.mp3" -ar 16000 -ac 1 "outputs/seg_001.wav"
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x568afb22c040] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'outputs/seg_001.mp3':
#   Duration: 00:00:11.35, start: 0.000000, bitrate: 64 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'outputs/seg_001.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=       1kB time=00:00:00.00 bitrate=N/A speed=N/A
# size=     355kB time=00:00:11.35 bitrate= 256.1kbits/s speed= 521x
# video:0kB audio:355kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.021472%
#
# >> ffmpeg -y -i "outputs/seg_002.mp3" -ar 16000 -ac 1 "outputs/seg_002.wav"
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x5d1b2dd13040] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'outputs/seg_002.mp3':
#   Duration: 00:00:12.29, start: 0.000000, bitrate: 64 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'outputs/seg_002.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=       1kB time=00:00:00.00 bitrate=N/A speed=   0x
# size=     384kB time=00:00:12.28 bitrate= 256.1kbits/s speed= 484x
# video:0kB audio:384kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.019836%
#
# >> ffmpeg -y -i "outputs/seg_003.mp3" -ar 16000 -ac 1 "outputs/seg_003.wav"
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x5a00011bc040] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'outputs/seg_003.mp3':
#   Duration: 00:00:11.06, start: 0.000000, bitrate: 64 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 64 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'outputs/seg_003.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=       1kB time=00:00:00.00 bitrate=N/A speed=   0x
# size=     346kB time=00:00:11.06 bitrate= 256.1kbits/s speed= 505x
# video:0kB audio:346kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.022031%
#
# Audio files: ['outputs/seg_000.wav', 'outputs/seg_001.wav', 'outputs/seg_002.wav', 'outputs/seg_003.wav']

# %% [markdown]
# ## 3) Run Wav2Lip per chunk
#
# - Provide a single face image (`CFG.face_image_path`).
# - We create a silent looped video from the still image at `CFG.target_fps`, long enough for each chunk's audio, then run Wav2Lip.

# %%
IMAGE = "/content/face.jpg"
# !wget -O /content/face.jpg https://thispersondoesnotexist.com/

# To use your own image:
# from google.colab import files; files.upload()
# IMAGE = "/content/your_image.jpg"
import os; assert os.path.isfile(IMAGE), "Image missing"; print("Using:", IMAGE)
# Out:
# --2025-08-12 18:43:31--  https://thispersondoesnotexist.com/
# Resolving thispersondoesnotexist.com (thispersondoesnotexist.com)... 172.67.130.241, 104.21.3.164, 2606:4700:3032::6815:3a4, ...
# Connecting to thispersondoesnotexist.com (thispersondoesnotexist.com)|172.67.130.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 529359 (517K) [image/jpeg]
# Saving to: ‘/content/face.jpg’
#
# /content/face.jpg   100%[===================>] 516.95K  1.09MB/s    in 0.5s
#
# 2025-08-12 18:43:32 (1.09 MB/s) - ‘/content/face.jpg’ saved [529359/529359]
#
# Using: /content/face.jpg

# %%
# %cd ..
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# %cd Wav2Lip
# !pip install -r requirements.txt
# %cd ..
# !mkdir -p Wav2Lip/checkpoints
# !wget -O Wav2Lip/checkpoints/wav2lip_gan.pth "https://github.com/Rudrabha/Wav2Lip/releases/download/v1.0/wav2lip_gan.pth"
# Out:
# /content
# fatal: destination path 'Wav2Lip' already exists and is not an empty directory.
# /content/Wav2Lip
# Collecting librosa==0.7.0 (from -r requirements.txt (line 1))
#   Using cached librosa-0.7.0.tar.gz (1.6 MB)
#   Preparing metadata (setup.py) ... done
# Collecting numpy==1.17.1 (from -r requirements.txt (line 2))
#   Using cached numpy-1.17.1.zip (6.5 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: opencv-contrib-python>=4.2.0.34 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (4.12.0.88)
# ERROR: Ignored the following yanked versions: 3.4.11.39, 3.4.17.61, 4.4.0.42, 4.4.0.44, 4.5.4.58, 4.5.5.62, 4.7.0.68
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement opencv-python==4.1.0.25 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.46, 4.5.1.48, 4.5.3.56, 4.5.4.60, 4.5.5.64, 4.6.0.66, 4.7.0.72, 4.8.0.74, 4.8.0.76, 4.8.1.78, 4.9.0.80, 4.10.0.82, 4.10.0.84, 4.11.0.86, 4.12.0.88)
# ERROR: No matching distribution found for opencv-python==4.1.0.25
# /content
# --2025-08-12 17:10:00--  https://github.com/Rudrabha/Wav2Lip/releases/download/v1.0/wav2lip_gan.pth
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-08-12 17:10:00 ERROR 404: Not Found.

# %%
# %cd ..
# Out:
# /content

# %%
from pathlib import Path
import os

# Define paths (adjust if your Wav2Lip repo is in another location)
ROOT = Path.cwd()
W2L_DIR = ROOT / "Wav2Lip"
W2L_CKPT = W2L_DIR / "checkpoints" / "wav2lip_gan.pth"
print(W2L_CKPT)

# Safety check
if not W2L_DIR.exists():
    raise FileNotFoundError(f"Wav2Lip directory not found at {W2L_DIR}. Please clone it first.")
if not W2L_CKPT.exists():
    raise FileNotFoundError(f"Checkpoint not found at {W2L_CKPT}. Please download it.")
# Out:
# /content/Wav2Lip/checkpoints/wav2lip_gan.pth

# %%
# 1) switch into the repo and ensure temp/ exists
# %cd /content/Wav2Lip
# !mkdir -p temp

# 2) run inference (use absolute paths for face/audio/outfile)
# !python inference.py \
  --checkpoint_path "checkpoints/wav2lip_gan.pth" \
  --face "/content/face.jpg" \
  --audio "/content/outputs/seg_000.wav" \
  --outfile "/content/outputs/seg_000.mp4" \
  --static True --resize_factor 2 --pads 0 10 0 0 --nosmooth

# 3) go back (optional)
# %cd /content
# Out:
# /content/Wav2Lip
# Using cpu for inference.
# Number of frames available for inference: 1
# (80, 701)
# Length of mel chunks: 216
#   0% 0/2 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:18<00:00, 18.38s/it]
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Model loaded
# 100% 2/2 [01:06<00:00, 33.49s/it]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/content/outputs/seg_000.wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:00:08.76, bitrate: 256 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
# Input #1, avi, from 'temp/result.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:08.64, start: 0.000000, bitrate: 1497 kb/s
#   Stream #1:0: Video: mpeg4 (Simple Profile) (DIVX / 0x58564944), yuv420p, 1024x1024 [SAR 1:1 DAR 1:1], 1494 kb/s, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #1:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5bf99559bbc0] -qscale is ignored, -crf is recommended.
# [libx264 @ 0x5bf99559bbc0] using SAR=1/1
# [libx264 @ 0x5bf99559bbc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5bf99559bbc0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5bf99559bbc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/outputs/seg_000.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 16000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame=  216 fps= 25 q=-1.0 Lsize=     549kB time=00:00:08.70 bitrate= 516.6kbits/s speed=1.01x
# video:462kB audio:80kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.220593%
# [libx264 @ 0x5bf99559bbc0] frame I:1     Avg QP:19.03  size: 46206
# [libx264 @ 0x5bf99559bbc0] frame P:86    Avg QP:18.07  size:  3351
# [libx264 @ 0x5bf99559bbc0] frame B:129   Avg QP:23.34  size:  1071
# [libx264 @ 0x5bf99559bbc0] consecutive B-frames: 17.6%  6.5%  5.6% 70.4%
# [libx264 @ 0x5bf99559bbc0] mb I  I16..4: 23.5% 76.2%  0.3%
# [libx264 @ 0x5bf99559bbc0] mb P  I16..4:  0.9%  2.6%  0.0%  P16..4: 14.7%  2.2%  1.2%  0.0%  0.0%    skip:78.4%
# [libx264 @ 0x5bf99559bbc0] mb B  I16..4:  0.3%  1.2%  0.0%  B16..8: 10.4%  0.4%  0.0%  direct: 0.1%  skip:87.7%  L0:52.1% L1:46.8% BI: 1.1%
# [libx264 @ 0x5bf99559bbc0] 8x8 transform intra:77.2% inter:95.8%
# [libx264 @ 0x5bf99559bbc0] coded y,uvDC,uvAC intra: 50.6% 59.7% 2.4% inter: 2.1% 2.7% 0.0%
# [libx264 @ 0x5bf99559bbc0] i16 v,h,dc,p: 15% 33% 16% 36%
# [libx264 @ 0x5bf99559bbc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 32% 34%  2%  2%  2%  3%  2%  2%
# [libx264 @ 0x5bf99559bbc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 31% 17%  2%  5%  3%  4%  2%  2%
# [libx264 @ 0x5bf99559bbc0] i8c dc,h,v,p: 45% 30% 20%  5%
# [libx264 @ 0x5bf99559bbc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5bf99559bbc0] ref P L0: 67.4%  4.6% 18.5%  9.5%
# [libx264 @ 0x5bf99559bbc0] ref B L0: 80.8% 13.7%  5.6%
# [libx264 @ 0x5bf99559bbc0] ref B L1: 93.8%  6.2%
# [libx264 @ 0x5bf99559bbc0] kb/s:437.60
# [aac @ 0x5bf9955a5d80] Qavg: 29869.168
# /content

# %%
from pathlib import Path
import subprocess, shlex

# Make run_cmd support cwd
def run_cmd(cmd: str, check=True, cwd=None):
    print(">>", cmd)
    proc = subprocess.run(
        shlex.split(cmd),
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        cwd=cwd
    )
    print(proc.stdout)
    if check and proc.returncode != 0:
        raise RuntimeError(f"Command failed: {cmd}")
    return proc.stdout

ROOT = Path("/content")
W2L_DIR = ROOT / "Wav2Lip"
W2L_CKPT = W2L_DIR / "checkpoints" / "wav2lip_gan.pth"
OUTDIR = ROOT / "outputs"

# ensure the repo-local temp directory exists (this is what inference.py expects)
(W2L_DIR / "temp").mkdir(parents=True, exist_ok=True)

def run_wav2lip_img(face_img: str, audio_wav: str, out_mp4: str):
    infer_py = str((W2L_DIR / "inference.py").resolve())
    cmd = (
        f'python "{infer_py}" '
        f'--checkpoint_path "{W2L_CKPT.resolve()}" '
        f'--face "{Path(face_img).resolve()}" '
        f'--audio "{Path(audio_wav).resolve()}" '
        f'--outfile "{Path(out_mp4).resolve()}" '
        f'--static True --nosmooth '
        f'--pads 0 15 0 0 '
        f'--resize_factor 2 '
        f'--wav2lip_batch_size 2 '
        f'--face_det_batch_size 1'
    )
    # IMPORTANT: run from inside the repo so relative "temp/" works
    run_cmd(cmd, cwd=str(W2L_DIR))

# %%
# Re-run just the first segment to confirm
run_wav2lip("/content/outputs/seg_003.mp4",
            "/content/outputs/seg_003.wav",
            "/content/outputs/seg_003.mp4")
# Out:
# >> python "/content/Wav2Lip/inference.py" --checkpoint_path "/content/Wav2Lip/checkpoints/wav2lip_gan.pth" --face "/content/outputs/seg_000.mp4" --audio "/content/outputs/seg_000.wav" --outfile "/content/outputs/seg_000.mp4" --static True --nosmooth --pads 0 10 0 0 --resize_factor 1 --wav2lip_batch_size 4 --face_det_batch_size 1
# Using cpu for inference.
# Reading video frames...
# Number of frames available for inference: 298
# (80, 701)
# Length of mel chunks: 216
#
#   0%|          | 0/54 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:16<00:00, 16.77s/it]
# 100%|██████████| 1/1 [00:16<00:00, 16.77s/it]
# [ WARN:0@23.026] global cap.cpp:779 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.12.0) /io/opencv/modules/videoio/src/cap_images.cpp:415: error: (-215:Assertion failed) !filename_pattern.empty() in function 'CvVideoWriter_Images'
#
#
#
#   2%|▏         | 1/54 [00:18<16:27, 18.63s/it]
#   4%|▎         | 2/54 [00:19<07:00,  8.09s/it]
#   6%|▌         | 3/54 [00:20<04:00,  4.72s/it]
#   7%|▋         | 4/54 [00:20<02:37,  3.15s/it]
#   9%|▉         | 5/54 [00:21<01:51,  2.27s/it]
#  11%|█         | 6/54 [00:22<01:24,  1.75s/it]
#  13%|█▎        | 7/54 [00:22<01:06,  1.42s/it]
/it]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/content/outputs/seg_000.wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:00:08.76, bitrate: 256 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
# temp/result.avi: No such file or directory
# Load checkpoint from: /content/Wav2Lip/checkpoints/wav2lip_gan.pth
# Model loaded

# %%
from pathlib import Path
import subprocess, shlex

# --- basics / paths ---
ROOT = Path("/content")
W2L_DIR = ROOT / "Wav2Lip"
W2L_CKPT = W2L_DIR / "checkpoints" / "wav2lip_gan.pth"
OUTDIR = Path(CFG.output_dir).resolve()

print("W2L_DIR:", W2L_DIR)
print("Checkpoint exists?", W2L_CKPT.exists())
print("Output dir:", OUTDIR)

# --- run shell with optional working dir ---
def run_cmd(cmd: str, check=True, cwd=None):
    print(">>", cmd)
    proc = subprocess.run(
        shlex.split(cmd),
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        cwd=cwd
    )
    print(proc.stdout)
    if check and proc.returncode != 0:
        raise RuntimeError(f"Command failed: {cmd}")
    return proc.stdout

# Ensure the repo-local temp dir exists (inference.py writes there)
(W2L_DIR / "temp").mkdir(parents=True, exist_ok=True)

# Detect whether this repo expects --static as a flag or value
def _static_takes_value(infer_py: str) -> bool:
    proc = subprocess.run(shlex.split(f'python "{infer_py}" -h'),
                          stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
    help_txt = proc.stdout or ""
    return "[--static STATIC]" in help_txt or "--static STATIC" in help_txt

# --- main Wav2Lip runner: use the FACE IMAGE directly ---
def run_wav2lip_img(face_img: str, audio_wav: str, out_mp4: str):
    infer_py = str((W2L_DIR / "inference.py").resolve())
    ckpt_abs = str(W2L_CKPT.resolve())
    face_abs = str(Path(face_img).resolve())
    wav_abs  = str(Path(audio_wav).resolve())
    out_abs  = str(Path(out_mp4).resolve())

    flags = [
        "--nosmooth",
        "--pads", "0", "15", "0", "0",   # a little forehead room helps
        "--resize_factor", "2",          # more stable on CPU
        "--wav2lip_batch_size", "2",
        "--face_det_batch_size", "1",
    ]
    if _static_takes_value(infer_py):
        flags = ["--static", "True"] + flags
    else:
        flags = ["--static"] + flags

    cmd = (
        f'python "{infer_py}" '
        f'--checkpoint_path "{ckpt_abs}" '
        f'--face "{face_abs}" '
        f'--audio "{wav_abs}" '
        f'--outfile "{out_abs}" '
        + " ".join(flags)
    )
    # Run from inside the repo so relative temp/ paths work
    run_cmd(cmd, cwd=str(W2L_DIR))

# --- generate each segment video ---
face_abs = Path(CFG.face_image_path).resolve()
if not face_abs.exists():
    raise FileNotFoundError(f"Face image not found: {face_abs}")

video_paths = []
for i in range(len(audio_paths)):
    wav = OUTDIR / f"seg_{i:03d}.wav"
    out_mp4 = OUTDIR / f"seg_{i:03d}.mp4"
    print(f"Rendering seg_{i:03d} ->", out_mp4)
    run_wav2lip_img(str(face_abs), str(wav), str(out_mp4))
    video_paths.append(str(out_mp4.resolve()))

print("Wav2Lip videos:", video_paths)
# Out:
# W2L_DIR: /content/Wav2Lip
# Checkpoint exists? True
# Output dir: /content/outputs
# Rendering seg_000 -> /content/outputs/seg_000.mp4
# >> python "/content/Wav2Lip/inference.py" --checkpoint_path "/content/Wav2Lip/checkpoints/wav2lip_gan.pth" --face "/content/face.jpg" --audio "/content/outputs/seg_000.wav" --outfile "/content/outputs/seg_000.mp4" --static True --nosmooth --pads 0 15 0 0 --resize_factor 2 --wav2lip_batch_size 2 --face_det_batch_size 1
# Using cpu for inference.
# Number of frames available for inference: 1
# (80,
#  80%|███████▉  | 86/108 [00:59<00:10,  2.19it/s]
#  81%|████████  | 87/108 [00:59<00:09,  2.27it/s]
#  81%|████████▏ | 88/108 [01:00<00:08,  2.32it/s]
#  82%|████████▏ | 89/108 [01:00<00:08,  2.33it/s]
#  83%|████████▎ | 90/108 [01:00<00:07,  2.37it/s]
#  84%|████████▍ | 91/108 [01:01<00:07,  2.33it/s]
#  85%|████████▌ | 92/108 [01:01<00:06,  2.34it/s]
#  86%|████████▌ | 93/108 [01:02<00:06,  2.35it/s]
#  87%|████████▋ | 94/108 [01:02<00:06,  2.33it/s]
#  88%|████████▊ | 95/108 [01:03<00:05,  2.34it/s]
#  89%|████████▉ | 96/108 [01:03<00:05,  2.32it/s]
#  90%|████████▉ | 97/108 [01:03<00:04,  2.36it/s]
#  91%|█████████ | 98/108 [01:04<00:04,  2.37it/s]
#  92%|█████████▏| 99/108 [01:04<00:03,  2.35it/s]
#  93%|█████████▎| 100/108 [01:05<00:03,  2.37it/s]
#  94%|█████████▎| 101/108 [01:05<00:02,  2.35it/s]
#  94%|█████████▍| 102/108 [01:06<00:02,  2.37it/s]
#  95%|█████████▌| 103/108 [01:06<00:02,  2.38it/s]
#  96%|█████████▋| 104/108 [01:06<00:01,  2.39it/s]
#  97%|█████████▋| 105/108 [01:07<00:01,  2.35it/s]
#  98%|█████████▊| 106/108 [01:07<00:00,  2.04it/s]
#  99%|█████████▉| 107/108 [01:08<00:00,  1.88it/s]
# 100%|██████████| 108/108 [01:09<00:00,  1.79it/s]
# 100%|██████████| 108/108 [01:09<00:00,  1.56it/s]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/content/outputs/seg_000.wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:00:08.76, bitrate: 256 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
# Input #1, avi, from 'temp/result.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:08.64, start: 0.000000, bitrate: 1497 kb/s
#   Stream #1:0: Video: mpeg4 (Simple Profile) (DIVX / 0x58564944), yuv420p, 1024x1024 [SAR 1:1 DAR 1:1], 1494 kb/s, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #1:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5cae7669ebc0] -qscale is ignored, -crf is recommended.
# [libx264 @ 0x5cae7669ebc0] using SAR=1/1
# [libx264 @ 0x5cae7669ebc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5cae7669ebc0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5cae7669ebc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/outputs/seg_000.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 16000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   47 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   58 fps= 52 q=28.0 size=       0kB time=00:00:00.32 bitrate=   1.2kbits/s speed=0.288x
# frame=   71 fps= 44 q=28.0 size=       0kB time=00:00:00.84 bitrate=   0.5kbits/s speed=0.519x
# frame=   86 fps= 40 q=28.0 size=       0kB time=00:00:01.47 bitrate=   0.3kbits/s speed=0.682x
# frame=  102 fps= 38 q=28.0 size=       0kB time=00:00:02.11 bitrate=   0.2kbits/s speed=0.785x
# frame=  118 fps= 37 q=28.0 size=       0kB time=00:00:02.75 bitrate=   0.1kbits/s speed=0.862x
# frame=  132 fps= 35 q=28.0 size=     256kB time=00:00:03.28 bitrate= 639.5kbits/s speed=0.881x
# frame=  147 fps= 35 q=28.0 size=     256kB time=00:00:03.90 bitrate= 537.3kbits/s speed=0.925x
# frame=  161 fps= 34 q=28.0 size=     256kB time=00:00:04.54 bitrate= 461.6kbits/s speed=0.96x
# frame=  177 fps= 34 q=28.0 size=     256kB time=00:00:05.18 bitrate= 404.6kbits/s speed=0.99x
# frame=  193 fps= 33 q=28.0 size=     256kB time=00:00:05.72 bitrate= 366.7kbits/s speed=0.982x
# frame=  209 fps= 33 q=28.0 size=     256kB time=00:00:06.46 bitrate= 324.5kbits/s speed=1.02x
# frame=  216 fps= 28 q=-1.0 Lsize=     548kB time=00:00:08.70 bitrate= 516.0kbits/s speed=1.13x
# video:462kB audio:80kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.213371%
# [libx264 @ 0x5cae7669ebc0] frame I:1     Avg QP:19.02  size: 46070
# [libx264 @ 0x5cae7669ebc0] frame P:91    Avg QP:17.99  size:  3153
# [libx264 @ 0x5cae7669ebc0] frame B:124   Avg QP:23.40  size:  1121
# [libx264 @ 0x5cae7669ebc0] consecutive B-frames: 21.8%  2.8%  6.9% 68.5%
# [libx264 @ 0x5cae7669ebc0] mb I  I16..4: 24.8% 74.9%  0.3%
# [libx264 @ 0x5cae7669ebc0] mb P  I16..4:  0.8%  2.2%  0.0%  P16..4: 14.2%  2.3%  1.0%  0.0%  0.0%    skip:79.4%
# [libx264 @ 0x5cae7669ebc0] mb B  I16..4:  0.3%  1.3%  0.0%  B16..8: 10.5%  0.4%  0.0%  direct: 0.1%  skip:87.4%  L0:53.0% L1:45.7% BI: 1.3%
# [libx264 @ 0x5cae7669ebc0] 8x8 transform intra:77.0% inter:96.0%
# [libx264 @ 0x5cae7669ebc0] coded y,uvDC,uvAC intra: 49.6% 59.7% 2.1% inter: 2.1% 2.8% 0.0%
# [libx264 @ 0x5cae7669ebc0] i16 v,h,dc,p: 17% 32% 16% 34%
# [libx264 @ 0x5cae7669ebc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 33% 34%  2%  2%  2%  3%  2%  2%
# [libx264 @ 0x5cae7669ebc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 34% 15%  2%  5%  3%  4%  2%  1%
# [libx264 @ 0x5cae7669ebc0] i8c dc,h,v,p: 44% 31% 19%  5%
# [libx264 @ 0x5cae7669ebc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5cae7669ebc0] ref P L0: 67.5%  4.9% 18.3%  9.3%
# [libx264 @ 0x5cae7669ebc0] ref B L0: 81.0% 13.5%  5.5%
# [libx264 @ 0x5cae7669ebc0] ref B L1: 93.5%  6.5%
# [libx264 @ 0x5cae7669ebc0] kb/s:437.00
# [aac @ 0x5cae766a8d80] Qavg: 29869.168
# Load checkpoint from: /content/Wav2Lip/checkpoints/wav2lip_gan.pth
# Model loaded
#
# Rendering seg_001 -> /content/outputs/seg_001.mp4
# >> python "/content/Wav2Lip/inference.py" --checkpoint_path "/content/Wav2Lip/checkpoints/wav2lip_gan.pth" --face "/content/face.jpg" --audio "/content/outputs/seg_001.wav" --outfile "/content/outputs/seg_001.mp4" --static True --nosmooth --pads 0 15 0 0 --resize_factor 2 --wav2lip_batch_size 2 --face_det_batch_size 1
# Using cpu for inference.
# Number of frames available for inference: 1
# (80, 909)
# Length of mel chunks: 281
#
#   0%|          | 0/141 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:17<00:00, 17.03s/it]
# 100%|██████████| 1/1 [00:17<00:00, 17.03s/it]
#
#   1%|          | 1/141 [00:18<43:55, 18.83s/it]
#   1%|▏         | 2/141 [00:19<18:50,  8.13s/it]
#   2%|▏         | 3/141 [00:20<10:48,  4.70s/it]
#   3%|▎         | 4/141 [00:20<07:03,  3.09s/it]
#   4%|▎         | 5/141 [00:21<04:59,  2.20s/it]
#   4%|▍         | 6/141 [00:21<03:34,  1.59s/it]
kb/s, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #1:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5c4532026280] -qscale is ignored, -crf is recommended.
# [libx264 @ 0x5c4532026280] using SAR=1/1
# [libx264 @ 0x5c4532026280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5c4532026280] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5c4532026280] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/outputs/seg_001.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 16000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   49 fps=0.0 q=28.0 size=       0kB time=-00:00:00.03 bitrate=N/A speed=N/A
# frame=   58 fps= 51 q=28.0 size=       0kB time=00:00:00.32 bitrate=   1.2kbits/s speed=0.284x
# frame=   64 fps= 39 q=28.0 size=       0kB time=00:00:00.57 bitrate=   0.7kbits/s speed=0.353x
# frame=   73 fps= 34 q=28.0 size=       0kB time=00:00:00.96 bitrate=   0.4kbits/s speed=0.449x
# frame=   83 fps= 31 q=28.0 size=       0kB time=00:00:01.34 bitrate=   0.3kbits/s speed=0.499x
# frame=   91 fps= 28 q=28.0 size=       0kB time=00:00:01.72 bitrate=   0.2kbits/s speed=0.535x
# frame=  103 fps= 28 q=28.0 size=       0kB time=00:00:02.12 bitrate=   0.2kbits/s speed=0.567x
# frame=  116 fps= 27 q=28.0 size=       0kB time=00:00:02.75 bitrate=   0.1kbits/s speed=0.643x
# frame=  133 fps= 28 q=28.0 size=     256kB time=00:00:03.39 bitrate= 618.4kbits/s speed=0.71x
# frame=  148 fps= 28 q=28.0 size=     256kB time=00:00:03.92 bitrate= 535.1kbits/s speed=0.74x
# frame=  164 fps= 28 q=28.0 size=     256kB time=00:00:04.67 bitrate= 449.0kbits/s speed=0.799x
# frame=  180 fps= 28 q=28.0 size=     256kB time=00:00:05.20 bitrate= 403.4kbits/s speed=0.815x
# frame=  195 fps= 28 q=28.0 size=     256kB time=00:00:05.82 bitrate= 360.2kbits/s speed=0.846x
# frame=  211 fps= 29 q=28.0 size=     256kB time=00:00:06.46 bitrate= 324.5kbits/s speed=0.874x
# frame=  228 fps= 29 q=28.0 size=     256kB time=00:00:07.12 bitrate= 294.6kbits/s speed=0.894x
# frame=  243 fps= 29 q=28.0 size=     512kB time=00:00:07.74 bitrate= 541.7kbits/s speed=0.914x
# frame=  257 fps= 29 q=28.0 size=     512kB time=00:00:08.38 bitrate= 500.3kbits/s speed=0.933x
# frame=  275 fps= 29 q=28.0 size=     512kB time=00:00:09.02 bitrate= 464.8kbits/s speed=0.945x
# frame=  281 fps= 26 q=-1.0 Lsize=     765kB time=00:00:11.32 bitrate= 552.9kbits/s speed=1.04x
# video:648kB audio:108kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.081738%
# [libx264 @ 0x5c4532026280] frame I:2     Avg QP:17.31  size: 58120
# [libx264 @ 0x5c4532026280] frame P:116   Avg QP:18.31  size:  3188
# [libx264 @ 0x5c4532026280] frame B:163   Avg QP:23.52  size:  1088
# [libx264 @ 0x5c4532026280] consecutive B-frames: 18.9% 10.7%  2.1% 68.3%
# [libx264 @ 0x5c4532026280] mb I  I16..4: 19.2% 76.0%  4.7%
# [libx264 @ 0x5c4532026280] mb P  I16..4:  0.8%  2.5%  0.0%  P16..4: 14.4%  2.4%  1.1%  0.0%  0.0%    skip:78.7%
# [libx264 @ 0x5c4532026280] mb B  I16..4:  0.3%  1.2%  0.0%  B16..8: 11.0%  0.4%  0.0%  direct: 0.1%  skip:87.0%  L0:56.2% L1:42.7% BI: 1.1%
# [libx264 @ 0x5c4532026280] 8x8 transform intra:77.4% inter:96.6%
# [libx264 @ 0x5c4532026280] coded y,uvDC,uvAC intra: 52.8% 60.5% 5.0% inter: 2.0% 2.6% 0.0%
# [libx264 @ 0x5c4532026280] i16 v,h,dc,p: 15% 32% 17% 36%
# [libx264 @ 0x5c4532026280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 32% 32%  2%  3%  2%  3%  2%  3%
# [libx264 @ 0x5c4532026280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 35%  9%  2%  6%  4%  5%  2%  2%
# [libx264 @ 0x5c4532026280] i8c dc,h,v,p: 43% 31% 21%  5%
# [libx264 @ 0x5c4532026280] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5c4532026280] ref P L0: 67.9%  4.6% 17.7%  9.7%
# [libx264 @ 0x5c4532026280] ref B L0: 79.7% 15.0%  5.3%
# [libx264 @ 0x5c4532026280] ref B L1: 94.7%  5.3%
# [libx264 @ 0x5c4532026280] kb/s:472.13
# [aac @ 0x5c45320304c0] Qavg: 27875.248
# Load checkpoint from: /content/Wav2Lip/checkpoints/wav2lip_gan.pth
# Model loaded
#
# Rendering seg_002 -> /content/outputs/seg_002.mp4
# >> python "/content/Wav2Lip/inference.py" --checkpoint_path "/content/Wav2Lip/checkpoints/wav2lip_gan.pth" --face "/content/face.jpg" --audio "/content/outputs/seg_002.wav" --outfile "/content/outputs/seg_002.mp4" --static True --nosmooth --pads 0 15 0 0 --resize_factor 2 --wav2lip_batch_size 2 --face_det_batch_size 1
# Using cpu for inference.
# Number of frames available for inference: 1
# (80, 984)
# Length of mel chunks: 304
#
#   0%|          | 0/152 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:17<00:00, 17.35s/it]
# 100%|██████████| 1/1 [00:17<00:00, 17.35s/it]
#
#   1%|          | 1/152 [00:19<49:17, 19.59s/it]
#   1%|▏         | 2/152 [00:20<21:17,  8.52s/it]
#   2%|▏         | 3/152 [00:21<12:17,  4.95s/it]
#   3%|▎         | 4/152 [00:21<08:05,  3.28s/it]
#   3%|▎         | 5/152 [00:22<05:41,  2.33s/it]
#   4%|▍         | 6/152 [00:23<04:16,  1.76s/it]
#   5%|▍         | 7/152 [00:23<03:14,  1.34s/it]
#   5%|▌         | 8/152 [00:23<02:30,  1.05s/it]
#   6%|▌         | 9/152 [00:24<02:01,  1.17it/s]
#   7%|▋         | 10/152 [00:24<01:42,  1.39it/s]
#   7%|▋         | 11/152 [00:25<01:29,  1.58it/s]
#   8%|▊         | 12/152 [00:25<01:19,  1.76it/s]
#   9%|▊         | 13/152 [00:26<01:13,  1.90it/s]
#   9%|▉         | 14/152 [00:26<01:08,  2.02it/s]
#  10%|▉         | 15/152 [00:26<01:04,  2.12it/s]
#  11%|█         | 16/152 [00:27<01:03,  2.16it/s]
#  11%|█         | 17/152 [00:27<01:01,  2.20it/s]
#  12%|█▏        | 18/152 [00:28<00:59,  2.26it/s]
#  12%|█▎        | 19/152 [00:28<00:58,  2.28it/s]
#  13%|█▎        | 20/152 [00:29<00:57,  2.31it/s]
#  14%|█▍        | 21/152 [00:29<00:56,  2.31it/s]
#  14%|█▍        | 22/152 [00:29<00:55,  2.34it/s]
mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 16000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   51 fps=0.0 q=28.0 size=       0kB time=00:00:00.06 bitrate=   6.0kbits/s speed=0.11x
# frame=   64 fps= 58 q=28.0 size=       0kB time=00:00:00.57 bitrate=   0.7kbits/s speed=0.524x
# frame=   78 fps= 48 q=28.0 size=       0kB time=00:00:01.21 bitrate=   0.3kbits/s speed=0.749x
# frame=   94 fps= 44 q=28.0 size=       0kB time=00:00:01.76 bitrate=   0.2kbits/s speed=0.823x
# frame=  109 fps= 41 q=28.0 size=       0kB time=00:00:02.36 bitrate=   0.2kbits/s speed=0.896x
# frame=  123 fps= 39 q=28.0 size=     256kB time=00:00:03.00 bitrate= 697.3kbits/s speed=0.948x
# frame=  139 fps= 38 q=28.0 size=     256kB time=00:00:03.56 bitrate= 589.2kbits/s speed=0.964x
# frame=  157 fps= 37 q=28.0 size=     256kB time=00:00:04.28 bitrate= 489.2kbits/s speed=1.02x
# frame=  170 fps= 36 q=28.0 size=     256kB time=00:00:04.80 bitrate= 437.0kbits/s speed=1.02x
# frame=  186 fps= 35 q=28.0 size=     256kB time=00:00:05.44 bitrate= 385.6kbits/s speed=1.04x
# frame=  202 fps= 35 q=28.0 size=     256kB time=00:00:06.08 bitrate= 345.0kbits/s speed=1.05x
# frame=  219 fps= 35 q=28.0 size=     256kB time=00:00:06.76 bitrate= 310.3kbits/s speed=1.07x
# frame=  233 fps= 34 q=28.0 size=     256kB time=00:00:07.36 bitrate= 285.0kbits/s speed=1.07x
# frame=  244 fps= 33 q=28.0 size=     512kB time=00:00:07.87 bitrate= 532.9kbits/s speed=1.07x
# frame=  256 fps= 32 q=28.0 size=     512kB time=00:00:08.25 bitrate= 508.1kbits/s speed=1.05x
# frame=  265 fps= 32 q=28.0 size=     512kB time=00:00:08.64 bitrate= 485.5kbits/s speed=1.03x
# frame=  273 fps= 31 q=28.0 size=     512kB time=00:00:09.02 bitrate= 464.8kbits/s speed=1.01x
# frame=  283 fps= 30 q=28.0 size=     512kB time=00:00:09.40 bitrate= 445.9kbits/s speed=0.997x
# frame=  292 fps= 29 q=28.0 size=     512kB time=00:00:09.79 bitrate= 428.4kbits/s speed=0.981x
# frame=  304 fps= 29 q=28.0 size=     512kB time=00:00:10.17 bitrate= 412.2kbits/s speed=0.97x
# frame=  304 fps= 26 q=-1.0 Lsize=     815kB time=00:00:12.22 bitrate= 546.1kbits/s speed=1.04x
# video:690kB audio:116kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.075869%
# [libx264 @ 0x560b3616a4c0] frame I:2     Avg QP:17.12  size: 59578
# [libx264 @ 0x560b3616a4c0] frame P:125   Avg QP:18.19  size:  3175
# [libx264 @ 0x560b3616a4c0] frame B:177   Avg QP:23.37  size:  1074
# [libx264 @ 0x560b3616a4c0] consecutive B-frames: 19.7%  7.2%  2.0% 71.1%
# [libx264 @ 0x560b3616a4c0] mb I  I16..4: 19.2% 76.0%  4.9%
# [libx264 @ 0x560b3616a4c0] mb P  I16..4:  0.8%  2.6%  0.0%  P16..4: 14.3%  2.3%  1.1%  0.0%  0.0%    skip:78.8%
# [libx264 @ 0x560b3616a4c0] mb B  I16..4:  0.3%  1.1%  0.0%  B16..8: 10.6%  0.4%  0.0%  direct: 0.1%  skip:87.5%  L0:57.4% L1:41.5% BI: 1.1%
# [libx264 @ 0x560b3616a4c0] 8x8 transform intra:77.0% inter:96.5%
# [libx264 @ 0x560b3616a4c0] coded y,uvDC,uvAC intra: 52.1% 60.2% 4.9% inter: 2.0% 2.6% 0.0%
# [libx264 @ 0x560b3616a4c0] i16 v,h,dc,p: 15% 30% 18% 37%
# [libx264 @ 0x560b3616a4c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 33% 32%  2%  3%  2%  3%  2%  3%
# [libx264 @ 0x560b3616a4c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 34%  9%  2%  5%  3%  4%  3%  2%
# [libx264 @ 0x560b3616a4c0] i8c dc,h,v,p: 43% 32% 20%  6%
# [libx264 @ 0x560b3616a4c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x560b3616a4c0] ref P L0: 68.4%  4.7% 17.5%  9.5%
# [libx264 @ 0x560b3616a4c0] ref B L0: 79.9% 15.5%  4.6%
# [libx264 @ 0x560b3616a4c0] ref B L1: 94.9%  5.1%
# [libx264 @ 0x560b3616a4c0] kb/s:464.52
# [aac @ 0x560b36174400] Qavg: 23861.127
# Load checkpoint from: /content/Wav2Lip/checkpoints/wav2lip_gan.pth
# Model loaded
#
# Rendering seg_003 -> /content/outputs/seg_003.mp4
# >> python "/content/Wav2Lip/inference.py" --checkpoint_path "/content/Wav2Lip/checkpoints/wav2lip_gan.pth" --face "/content/face.jpg" --audio "/content/outputs/seg_003.wav" --outfile "/content/outputs/seg_003.mp4" --static True --nosmooth --pads 0 15 0 0 --resize_factor 2 --wav2lip_batch_size 2 --face_det_batch_size 1
# Using cpu for inference.
# Number of frames available for inference: 1
# (80, 886)
# Length of mel chunks: 274
#
#   0%|          | 0/137 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:17<00:00, 17.50s/it]
# 100%|██████████| 1/1 [00:17<00:00, 17.50s/it]
#
#   1%|          | 1/137 [00:21<48:00, 21.18s/it]
#   1%|▏         | 2/137 [00:22<21:21,  9.49s/it]
#   2%|▏         | 3/137 [00:23<12:03,  5.40s/it]
#   3%|▎         | 4/137 [00:23<07:40,  3.47s/it]
#   4%|▎         | 5/137 [00:24<05:19,  2.42s/it]
#   4%|▍         | 6/137 [00:24<04:00,  1.84s/it]
#   5%|▌         | 7/137 [00:25<03:22,  1.56s/it]
#   6%|▌         | 8/137 [00:26<02:54,  1.35s/it]
#   7%|▋         | 9/137 [00:27<02:33,  1.20s/it]
#   7%|▋         | 10/137 [00:28<02:26,  1.16s/it]
#   8%|▊         | 11/137 [00:29<02:06,  1.00s/it]
#   9%|▉         | 12/137 [00:29<01:52,  1.12it/s]
#   9%|▉         | 13/137 [00:30<01:35,  1.30it/s]
#  10%|█         | 14/137 [00:30<01:22,  1.49it/s]
#  11%|█         | 15/137 [00:31<01:11,  1.70it/s]
#  12%|█▏        | 16/137 [00:31<01:04,  1.86it/s]
#  12%|█▏        | 17/137 [00:32<00:59,  2.00it/s]
#  13%|█▎        | 18/137 [00:32<00:56,  2.12it/s]
#  14%|█▍        | 19/137 [00:32<00:54,  2.17it/s]
#  15%|█▍        | 20/137 [00:33<00:52,  2.25it/s]
#  82%|████████▏ | 112/137 [01:15<00:10,  2.39it/s]
#  82%|████████▏ | 113/137 [01:15<00:10,  2.37it/s]
#  83%|████████▎ | 114/137 [01:15<00:09,  2.38it/s]
#  84%|████████▍ | 115/137 [01:16<00:09,  2.37it/s]
#  85%|████████▍ | 116/137 [01:16<00:08,  2.39it/s]
#  85%|████████▌ | 117/137 [01:17<00:08,  2.41it/s]
#  86%|████████▌ | 118/137 [01:17<00:08,  2.31it/s]
#  87%|████████▋ | 119/137 [01:18<00:08,  2.03it/s]
#  88%|████████▊ | 120/137 [01:18<00:09,  1.86it/s]
#  88%|████████▊ | 121/137 [01:19<00:08,  1.79it/s]
#  89%|████████▉ | 122/137 [01:20<00:08,  1.70it/s]
#  90%|████████▉ | 123/137 [01:20<00:07,  1.78it/s]
#  91%|█████████ | 124/137 [01:21<00:06,  1.92it/s]
#  91%|█████████ | 125/137 [01:21<00:05,  2.05it/s]
#  92%|█████████▏| 126/137 [01:21<00:05,  2.11it/s]
#  93%|█████████▎| 127/137 [01:22<00:04,  2.19it/s]
#  93%|█████████▎| 128/137 [01:22<00:04,  2.22it/s]
#  94%|█████████▍| 129/137 [01:23<00:03,  2.29it/s]
#  95%|█████████▍| 130/137 [01:23<00:03,  2.30it/s]
#  96%|█████████▌| 131/137 [01:24<00:02,  2.31it/s]
#  96%|█████████▋| 132/137 [01:24<00:02,  2.32it/s]
#  97%|█████████▋| 133/137 [01:24<00:01,  2.31it/s]
#  98%|█████████▊| 134/137 [01:25<00:01,  2.34it/s]
#  99%|█████████▊| 135/137 [01:25<00:00,  2.35it/s]
#  99%|█████████▉| 136/137 [01:26<00:00,  2.32it/s]
# 100%|██████████| 137/137 [01:26<00:00,  2.35it/s]
# 100%|██████████| 137/137 [01:26<00:00,  1.58it/s]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/content/outputs/seg_003.wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:00:11.06, bitrate: 256 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
# Input #1, avi, from 'temp/result.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:10.96, start: 0.000000, bitrate: 1511 kb/s
#   Stream #1:0: Video: mpeg4 (Simple Profile) (DIVX / 0x58564944), yuv420p, 1024x1024 [SAR 1:1 DAR 1:1], 1507 kb/s, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #1:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5a9a1e8d0280] -qscale is ignored, -crf is recommended.
# [libx264 @ 0x5a9a1e8d0280] using SAR=1/1
# [libx264 @ 0x5a9a1e8d0280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5a9a1e8d0280] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5a9a1e8d0280] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/outputs/seg_003.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 16000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   47 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   59 fps= 52 q=28.0 size=       0kB time=00:00:00.36 bitrate=   1.1kbits/s speed=0.314x
# frame=   74 fps= 45 q=28.0 size=       0kB time=00:00:00.96 bitrate=   0.4kbits/s speed=0.582x
# frame=   89 fps= 41 q=28.0 size=       0kB time=00:00:01.60 bitrate=   0.2kbits/s speed=0.742x
# frame=  106 fps= 40 q=28.0 size=       0kB time=00:00:02.24 bitrate=   0.2kbits/s speed=0.835x
# frame=  119 fps= 37 q=28.0 size=       0kB time=00:00:02.88 bitrate=   0.1kbits/s speed=0.903x
# frame=  132 fps= 36 q=28.0 size=     256kB time=00:00:03.39 bitrate= 618.4kbits/s speed=0.919x
# frame=  142 fps= 34 q=28.0 size=     256kB time=00:00:03.77 bitrate= 555.5kbits/s speed=0.897x
# frame=  153 fps= 32 q=28.0 size=     256kB time=00:00:04.16 bitrate= 504.2kbits/s speed=0.873x
# frame=  161 fps= 31 q=28.0 size=     256kB time=00:00:04.44 bitrate= 472.4kbits/s speed=0.843x
# frame=  170 fps= 29 q=28.0 size=     256kB time=00:00:04.80 bitrate= 437.0kbits/s speed=0.827x
# frame=  180 fps= 28 q=28.0 size=     256kB time=00:00:05.31 bitrate= 394.9kbits/s speed=0.837x
# frame=  190 fps= 27 q=28.0 size=     256kB time=00:00:05.69 bitrate= 368.2kbits/s speed=0.82x
# frame=  203 fps= 27 q=28.0 size=     256kB time=00:00:06.20 bitrate= 337.9kbits/s speed=0.832x
# frame=  219 fps= 27 q=28.0 size=     256kB time=00:00:06.76 bitrate= 310.3kbits/s speed=0.846x
# frame=  235 fps= 28 q=28.0 size=     512kB time=00:00:07.40 bitrate= 566.8kbits/s speed=0.867x
# frame=  250 fps= 28 q=28.0 size=     512kB time=00:00:08.00 bitrate= 524.3kbits/s speed=0.882x
# frame=  266 fps= 28 q=28.0 size=     512kB time=00:00:08.64 bitrate= 485.5kbits/s speed=0.903x
# frame=  274 fps= 25 q=-1.0 Lsize=     756kB time=00:00:11.00 bitrate= 562.5kbits/s speed=0.994x
# video:644kB audio:103kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.075797%
# [libx264 @ 0x5a9a1e8d0280] frame I:2     Avg QP:17.54  size: 56814
# [libx264 @ 0x5a9a1e8d0280] frame P:115   Avg QP:18.28  size:  3301
# [libx264 @ 0x5a9a1e8d0280] frame B:157   Avg QP:23.48  size:  1057
# [libx264 @ 0x5a9a1e8d0280] consecutive B-frames: 19.0% 13.1%  2.2% 65.7%
# [libx264 @ 0x5a9a1e8d0280] mb I  I16..4: 18.8% 76.6%  4.6%
# [libx264 @ 0x5a9a1e8d0280] mb P  I16..4:  0.9%  2.8%  0.0%  P16..4: 14.5%  2.4%  1.2%  0.0%  0.0%    skip:78.2%
# [libx264 @ 0x5a9a1e8d0280] mb B  I16..4:  0.2%  1.1%  0.0%  B16..8: 11.0%  0.4%  0.0%  direct: 0.1%  skip:87.2%  L0:57.0% L1:41.8% BI: 1.2%
# [libx264 @ 0x5a9a1e8d0280] 8x8 transform intra:77.1% inter:96.5%
# [libx264 @ 0x5a9a1e8d0280] coded y,uvDC,uvAC intra: 53.2% 60.5% 4.7% inter: 2.0% 2.6% 0.0%
# [libx264 @ 0x5a9a1e8d0280] i16 v,h,dc,p: 15% 31% 17% 37%
# [libx264 @ 0x5a9a1e8d0280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 33% 31%  2%  3%  2%  3%  2%  3%
# [libx264 @ 0x5a9a1e8d0280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 34% 10%  3%  4%  3%  5%  2%  2%
# [libx264 @ 0x5a9a1e8d0280] i8c dc,h,v,p: 42% 32% 20%  6%
# [libx264 @ 0x5a9a1e8d0280] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5a9a1e8d0280] ref P L0: 68.5%  4.8% 17.3%  9.4%
# [libx264 @ 0x5a9a1e8d0280] ref B L0: 80.4% 15.3%  4.3%
# [libx264 @ 0x5a9a1e8d0280] ref B L1: 95.5%  4.5%
# [libx264 @ 0x5a9a1e8d0280] kb/s:481.21
# [aac @ 0x5a9a1e8da4c0] Qavg: 28676.350
# Load checkpoint from: /content/Wav2Lip/checkpoints/wav2lip_gan.pth
# Model loaded
#
# Wav2Lip videos: ['/content/outputs/seg_000.mp4', '/content/outputs/seg_001.mp4', '/content/outputs/seg_002.mp4', '/content/outputs/seg_003.mp4']

# %% [markdown]
# ## 4) Stitch with clean cross-fades (video + audio)
# We use **FFmpeg** `xfade` for video and `acrossfade` for audio to ensure smooth transitions.

# %%
from pathlib import Path
import json, subprocess, shlex

OUTDIR = Path("/content/outputs")

def has_audio(p: Path) -> bool:
    cmd = f'ffprobe -v error -select_streams a -show_entries stream=codec_type -of json "{p}"'
    out = subprocess.run(shlex.split(cmd), stdout=subprocess.PIPE, text=True).stdout
    try:
        j = json.loads(out)
        return bool(j.get("streams"))
    except:
        return False

# Build fixed_paths from your segments and ensure each has audio (remux if needed)
fixed_paths = []
i = 0
while True:
    mp4 = OUTDIR / f"seg_{i:03d}.mp4"
    wav = OUTDIR / f"seg_{i:03d}.wav"
    if not mp4.exists(): break
    if not has_audio(mp4) and wav.exists():
        mp4_aud = OUTDIR / f"seg_{i:03d}_aud.mp4"
        subprocess.run(shlex.split(
            f'ffmpeg -y -i "{mp4}" -i "{wav}" -shortest -map 0:v:0 -map 1:a:0 -c:v copy -c:a aac -b:a 192k "{mp4_aud}"'
        ), check=True)
        fixed_paths.append(str(mp4_aud))
    else:
        fixed_paths.append(str(mp4))
    i += 1

print("Segments to stitch:", fixed_paths)
assert fixed_paths, "No segment videos found. Generate seg_000.mp4, seg_001.mp4, ... first."
# Out:
# Segments to stitch: ['/content/outputs/seg_000.mp4', '/content/outputs/seg_001.mp4', '/content/outputs/seg_002.mp4', '/content/outputs/seg_003.mp4']

# %%
stitched_path = str((OUTDIR / "stitched_raw.mp4").resolve())
stitch_with_crossfades(fixed_paths, crossfade_s=CFG.crossfade_s, out_path=stitched_path, target_fps=CFG.target_fps)
print("Stitched:", stitched_path)
# Out:
# ffmpeg -y -i "/content/outputs/seg_000.mp4" -i "/content/outputs/seg_001.mp4" -i "/content/outputs/seg_002.mp4" -i "/content/outputs/seg_003.mp4" -filter_complex "[0:v]fps=25,format=yuv420p,setpts=PTS-STARTPTS[v0];[0:a]aformat=sample_fmts=fltp:sample_rates=44100:channel_layouts=stereo,asetpts=PTS-STARTPTS[a0];[1:v]fps=25,format=yuv420p,setpts=PTS-STARTPTS[v1];[1:a]aformat=sample_fmts=fltp:sample_rates=44100:channel_layouts=stereo,asetpts=PTS-STARTPTS[a1];[2:v]fps=25,format=yuv420p,setpts=PTS-STARTPTS[v2];[2:a]aformat=sample_fmts=fltp:sample_rates=44100:channel_layouts=stereo,asetpts=PTS-STARTPTS[a2];[3:v]fps=25,format=yuv420p,setpts=PTS-STARTPTS[v3];[3:a]aformat=sample_fmts=fltp:sample_rates=44100:channel_layouts=stereo,asetpts=PTS-STARTPTS[a3];[v0][v1]xfade=transition=fade:duration=0.75:offset=8.010[v1];[a0][a1]acrossfade=d=0.75:c1=tri:c2=tri[a1];[v1][v2]xfade=transition=fade:duration=0.75:offset=18.612[v2];[a1][a2]acrossfade=d=0.75:c1=tri:c2=tri[a2];[v2][v3]xfade=transition=fade:duration=0.75:offset=30.150[v3];[a2][a3]acrossfade=d=0.75:c1=tri:c2=tri[a3]" -map "[v3]" -map "[a3]" -c:v libx264 -crf 18 -preset veryfast -c:a aac -b:a 192k "/content/outputs/stitched_raw.mp4"
# Stitched: /content/outputs/stitched_raw.mp4

# %% [markdown]
# ## 5) Loudness normalisation (EBU R128)
# We extract, normalise, and re-mux audio to avoid re-encoding video again.

# %%
tmp_audio = str((OUTDIR / "tmp_audio.wav").resolve())
norm_audio = str((OUTDIR / "tmp_audio_norm.wav").resolve())
final_path = str((OUTDIR / "final_normalised.mp4").resolve())
final_fast = str((OUTDIR / "final_faststart.mp4").resolve())

# extract
subprocess.run(shlex.split(f'ffmpeg -y -i "{stitched_path}" -vn -ac 2 -ar 44100 "{tmp_audio}"'), check=True)

# normalize
subprocess.run(shlex.split(
    f'ffmpeg -y -i "{tmp_audio}" -af "loudnorm=I={CFG.audio_lufs}:TP=-1.5:LRA=11:print_format=summary" "{norm_audio}"'
), check=True)

# remux normalized audio with copy of video
subprocess.run(shlex.split(
    f'ffmpeg -y -i "{stitched_path}" -i "{norm_audio}" -map 0:v:0 -map 1:a:0 -c:v copy -c:a aac -b:a 192k "{final_path}"'
), check=True)

# faststart for playback
subprocess.run(shlex.split(
    f'ffmpeg -y -i "{final_path}" -c copy -movflags +faststart "{final_fast}"'
), check=True)

print("Final video:", final_fast)
# Out:
# Final video: /content/outputs/final_faststart.mp4

# %%
# !ffmpeg -y -i "/content/outputs/stitched_raw.mp4" \
  -vf "scale=1280:720:flags=bicubic,format=yuv420p" -r 25 \
  -c:v libx264 -profile:v high -level 4.0 -preset veryfast -crf 20 \
  -c:a aac -b:a 160k -ar 44100 -ac 2 \
  -movflags +faststart "/content/outputs/final_windows.mp4"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/outputs/stitched_raw.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:41.27, start: 0.000000, bitrate: 669 kb/s
#   Stream #0:0(und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv444p, 1024x1024 [SAR 1:1 DAR 1:1], 528 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 136 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5a6fdff9c580] using SAR=9/16
# [libx264 @ 0x5a6fdff9c580] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5a6fdff9c580] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5a6fdff9c580] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=20.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/outputs/final_windows.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1280x720 [SAR 9:16 DAR 1:1], q=2-31, 25 fps, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 160 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# [mp4 @ 0x5a6fdffafbc0] Starting second pass: moving the moov atom to the beginning of the file
# frame= 1028 fps= 49 q=-1.0 Lsize=    2467kB time=00:00:41.26 bitrate= 489.8kbits/s speed=1.97x
# video:1720kB audio:712kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.440709%
# [libx264 @ 0x5a6fdff9c580] frame I:5     Avg QP:15.21  size: 75833
# [libx264 @ 0x5a6fdff9c580] frame P:271   Avg QP:16.48  size:  3007
# [libx264 @ 0x5a6fdff9c580] frame B:752   Avg QP:20.16  size:   753
# [libx264 @ 0x5a6fdff9c580] consecutive B-frames:  0.5%  4.9%  3.2% 91.4%
# [libx264 @ 0x5a6fdff9c580] mb I  I16..4:  9.3% 36.9% 53.8%
# [libx264 @ 0x5a6fdff9c580] mb P  I16..4:  1.1%  5.5%  0.2%  P16..4:  8.0%  4.3%  1.3%  0.0%  0.0%    skip:79.7%
# [libx264 @ 0x5a6fdff9c580] mb B  I16..4:  0.2%  0.8%  0.0%  B16..8:  3.5%  1.3%  0.0%  direct: 1.0%  skip:93.2%  L0:44.0% L1:50.3% BI: 5.8%
# [libx264 @ 0x5a6fdff9c580] 8x8 transform intra:73.6% inter:41.0%
# [libx264 @ 0x5a6fdff9c580] coded y,uvDC,uvAC intra: 63.0% 57.1% 11.4% inter: 0.7% 1.5% 0.0%
# [libx264 @ 0x5a6fdff9c580] i16 v,h,dc,p: 16% 41% 16% 27%
# [libx264 @ 0x5a6fdff9c580] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 56%  9%  3%  4%  2%  9%  2%  4%
# [libx264 @ 0x5a6fdff9c580] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 37%  8%  6%  6%  4% 10%  5%  9%
# [libx264 @ 0x5a6fdff9c580] i8c dc,h,v,p: 40% 44%  8%  8%
# [libx264 @ 0x5a6fdff9c580] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5a6fdff9c580] kb/s:342.50
# [aac @ 0x5a6fdffa7100] Qavg: 48446.164

# %%
from google.colab import files
files.download("/content/outputs/final_faststart.mp4")

# %% [markdown]
# ## Bonus: Verify identical FPS across all Wav2Lip segments

# %%
#@title Verify identical FPS via ffprobe
fps_values = []
for v in video_paths:
    fps = ffprobe_fps(v)
    fps_values.append((v, fps))
fps_values
# Out:
# >> ffprobe -v error -select_streams v:0 -show_entries stream=r_frame_rate -of json "/content/outputs/seg_000.mp4"
# {
#     "programs": [
#
#     ],
#     "streams": [
#         {
#             "r_frame_rate": "25/1"
#         }
#     ]
# }
#
# >> ffprobe -v error -select_streams v:0 -show_entries stream=r_frame_rate -of json "/content/outputs/seg_001.mp4"
# {
#     "programs": [
#
#     ],
#     "streams": [
#         {
#             "r_frame_rate": "25/1"
#         }
#     ]
# }
#
# >> ffprobe -v error -select_streams v:0 -show_entries stream=r_frame_rate -of json "/content/outputs/seg_002.mp4"
# {
#     "programs": [
#
#     ],
#     "streams": [
#         {
#             "r_frame_rate": "25/1"
#         }
#     ]
# }
#
# >> ffprobe -v error -select_streams v:0 -show_entries stream=r_frame_rate -of json "/content/outputs/seg_003.mp4"
# {
#     "programs": [
#
#     ],
#     "streams": [
#         {
#             "r_frame_rate": "25/1"
#         }
#     ]
# }
# [('/content/outputs/seg_000.mp4', 25.0),
#  ('/content/outputs/seg_001.mp4', 25.0),
#  ('/content/outputs/seg_002.mp4', 25.0),
#  ('/content/outputs/seg_003.mp4', 25.0)]

# %% [markdown]
# ### How to use
# 1. Upload a **front-facing face image** and set `CFG.face_image_path` accordingly.
# 2. Tweak `CFG.prompt`, `CFG.segments`, and `CFG.segment_chars`.
# 3. Run the notebook cells in order.
# 4. Your final video will be at `outputs/final_normalised.mp4`.
#
# If `gTTS` fails in your environment, swap it with **Coqui TTS** or **Piper**.
